# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('PriceData.csv',index_col=0)
df.head()
# Out:
#           ZEE_DA_EUR  NBP_DA_EUR  TTF_DA_EUR  Gaspool_DA_EUR  NCG_DA_EUR  \
# Date
# 01/01/15         NaN         NaN         NaN             NaN         NaN
# 02/01/15     20.1050    20.64791      20.300          20.550      20.800
# 05/01/15     20.0005    20.44590      19.825          20.525      20.400
# 06/01/15     19.3230    19.79763      19.300          19.625      19.950
# 07/01/15     19.3490    19.84571      19.100          19.800      19.625
#
#           PEGN_DA_EUR  PSV_DA  TRS_DA   CO2  Coal_API2    ...      NCG_Q2_18  \
# Date                                                      ...
# 01/01/15          NaN     NaN     NaN   NaN        NaN    ...            NaN
# 02/01/15       21.250   23.45     NaN  7.01      64.70    ...            NaN
# 05/01/15       20.775   22.70     NaN  6.90      62.50    ...            NaN
# 06/01/15       20.350   22.95     NaN  6.77      61.00    ...            NaN
# ...

# %%
df.index = pd.to_datetime(df.index, format='%d/%m/%y')

# %%
df.iloc[:,0:3].dropna().plot(figsize=(15,8))

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go

data = [go.Scatter( x=df.index, y=df[column].dropna(), name=column) for column in df.columns[:6]]    
py.iplot(data)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...

# %%
df['ZEE_DA_EUR_MA_20'] = df['ZEE_DA_EUR'].rolling(window=20, min_periods=15).mean()
df['ZEE_DA_EUR_STD_20_sup'] = df['ZEE_DA_EUR_MA_20'] + 2*df['ZEE_DA_EUR'].rolling(window=20, min_periods=15).std()
df['ZEE_DA_EUR_STD_20_inf'] = df['ZEE_DA_EUR_MA_20'] - 2*df['ZEE_DA_EUR'].rolling(window=20, min_periods=15).std()

# %%
data = [go.Scatter( x=df.index, y=df['ZEE_DA_EUR'], name='ZEE_DA_EUR'),
        go.Scatter( x=df.index, y=df['ZEE_DA_EUR_MA_20'], name='ZEE_DA_EUR_MA_20'),
        go.Scatter( x=df.index, y=df['ZEE_DA_EUR_STD_20_sup'], name='ZEE_DA_EUR_STD_20_sup',marker={'color':'pink'}),
        go.Scatter( x=df.index, y=df['ZEE_DA_EUR_STD_20_inf'], name='ZEE_DA_EUR_STD_20_inf',marker={'color':'pink'},fill='tonexty'),
       ]    
py.iplot(data)
# Out:
# <div id="1553dea3-020b-40fb-b5ea-e08410419714" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1553dea3-020b-40fb-b5ea-e08410419714", [{"type": "scatter", "name": "ZEE_DA_EUR", "y": [null, 20.105, 20.0005, 19.323, 19.349, 19.1735, 19.2905, 19.952, 20.208, 20.609, 19.936, 20.0045, 18.8975, 19.0405, 19.1055, 19.42, 19.3175, 19.5635, 20.0315, 20.4455, 20.705, 21.1275, 21.0915, 21.13, 21.2, 22.151, 21.62, 21.5765, 22.022, 23.189, 24.399, 23.513, 23.14, 22.7015, 22.8945, 22.0215, 22.3365, 22.0285, 22.427, 23.1795, 23.5115, 23.405, 22.5885, 21.929000000000002, 22.2215, 21.4315, 21.217, 21.7265, 21.884, 22.0875, 21.969, 21.354, 21.275, 21.0945, 21.533, 20.9055, 20.7385, 21.147, 21.4665, 21.285999999999998, 21.8635, 21.329, 21.585, 22.1395, 22.671, 22.3915, null, null, 21.763, 21.927, 22.1165, 22.4775, 22.
# ...
